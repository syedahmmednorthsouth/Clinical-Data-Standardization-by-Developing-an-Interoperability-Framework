# %%
# !pip install dataframe_image
# Out:
# Requirement already satisfied: dataframe_image in d:\my new project workplace\vis-esrd-lab\salt_c\env\lib\site-packages (0.1.2)
# Requirement already satisfied: matplotlib>=3.1 in d:\my new project workplace\vis-esrd-lab\salt_c\env\lib\site-packages (from dataframe_image) (3.5.3)
# Requirement already satisfied: mistune in d:\my new project workplace\vis-esrd-lab\salt_c\env\lib\site-packages (from dataframe_image) (2.0.4)
# Requirement already satisfied: aiohttp in d:\my new project workplace\vis-esrd-lab\salt_c\env\lib\site-packages (from dataframe_image) (3.8.3)
# Requirement already satisfied: packaging in d:\my new project workplace\vis-esrd-lab\salt_c\env\lib\site-packages (from dataframe_image) (21.3)
# Requirement already satisfied: nbconvert>=5 in d:\my new project workplace\vis-esrd-lab\salt_c\env\lib\site-packages (from dataframe_image) (7.0.0)
# Requirement already satisfied: beautifulsoup4 in d:\my new project workplace\vis-esrd-lab\salt_c\env\lib\site-packages (from dataframe_image) (4.11.1)
# Requirement already satisfied: pandas>=0.24 in d:\my new project workplace\vis-esrd-lab\salt_c\env\lib\site-packages (from dataframe_image) (1.4.3)
# Requirement already satisfied: requests in d:\my new project workplace\vis-esrd-lab\salt_c\env\lib\site-packages (from dataframe_image) (2.28.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\my new project workplace\vis-esrd-lab\salt_c\env\lib\site-packages (from matplotlib>=3.1->dataframe_image) (4.37.1)
# Requirement already satisfied: cycler>=0.10 in d:\my new project workplace\vis-esrd-lab\salt_c\env\lib\site-packages (from matplotlib>=3.1->dataframe_image) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in d:\my new project workplace\vis-esrd-lab\salt_c\env\lib\site-packages (from matplotlib>=3.1->dataframe_image) (9.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in d:\my new project workplace\vis-esrd-lab\salt_c\env\lib\site-packages (from matplotlib>=3.1->dataframe_image) (2.8.2)
# Requirement already satisfied: numpy>=1.17 in d:\my new project workplace\vis-esrd-lab\salt_c\env\lib\site-packages (from matplotlib>=3.1->dataframe_image) (1.23.2)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\my new project workplace\vis-esrd-lab\salt_c\env\lib\site-packages (from matplotlib>=3.1->dataframe_image) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\my new project workplace\vis-esrd-lab\salt_c\env\lib\site-packages (from matplotlib>=3.1->dataframe_image) (1.4.4)
# Requirement already satisfied: traitlets>=5.0 in d:\my new project workplace\vis-esrd-lab\salt_c\env\lib\site-packages (from nbconvert>=5->dataframe_image) (5.3.0)
# Requirement already satisfied: defusedxml in d:\my new project workplace\vis-esrd-lab\salt_c\env\lib\site-packages (from nbconvert>=5->dataframe_image) (0.7.1)
# Requirement already satisfied: markupsafe>=2.0 in d:\my new project workplace\vis-esrd-lab\salt_c\env\lib\site-packages (from nbconvert>=5->dataframe_image) (2.1.1)
# Requirement already satisfied: nbclient>=0.5.0 in d:\my new project workplace\vis-esrd-lab\salt_c\env\lib\site-packages (from nbconvert>=5->dataframe_image) (0.6.7)
# Requirement already satisfied: tinycss2 in d:\my new project workplace\vis-esrd-lab\salt_c\env\lib\site-packages (from nbconvert>=5->dataframe_image) (1.1.1)
# Requirement already satisfied: nbformat>=5.1 in d:\my new project workplace\vis-esrd-lab\salt_c\env\lib\site-packages (from nbconvert>=5->dataframe_image) (5.4.0)
# Requirement already satisfied: jupyterlab-pygments in d:\my new project workplace\vis-esrd-lab\salt_c\env\lib\site-packages (from nbconvert>=5->dataframe_image) (0.2.2)
# Requirement already satisfied: jupyter-core>=4.7 in d:\my new project workplace\vis-esrd-lab\salt_c\env\lib\site-packages (from nbconvert>=5->dataframe_image) (4.11.1)
# Requirement already satisfied: bleach in d:\my new project workplace\vis-esrd-lab\salt_c\env\lib\site-packages (from nbconvert>=5->dataframe_image) (5.0.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in d:\my new project workplace\vis-esrd-lab\salt_c\env\lib\site-packages (from nbconvert>=5->dataframe_image) (1.5.0)
# Requirement already satisfied: lxml in d:\my new project workplace\vis-esrd-lab\salt_c\env\lib\site-packages (from nbconvert>=5->dataframe_image) (4.9.1)
# Requirement already satisfied: pygments>=2.4.1 in d:\my new project workplace\vis-esrd-lab\salt_c\env\lib\site-packages (from nbconvert>=5->dataframe_image) (2.13.0)
# Requirement already satisfied: jinja2>=3.0 in d:\my new project workplace\vis-esrd-lab\salt_c\env\lib\site-packages (from nbconvert>=5->dataframe_image) (3.1.2)
# Requirement already satisfied: pywin32>=1.0 in d:\my new project workplace\vis-esrd-lab\salt_c\env\lib\site-packages (from jupyter-core>=4.7->nbconvert>=5->dataframe_image) (304)
# Requirement already satisfied: jupyter-client>=6.1.5 in d:\my new project workplace\vis-esrd-lab\salt_c\env\lib\site-packages (from nbclient>=0.5.0->nbconvert>=5->dataframe_image) (7.3.5)
# Requirement already satisfied: nest-asyncio in d:\my new project workplace\vis-esrd-lab\salt_c\env\lib\site-packages (from nbclient>=0.5.0->nbconvert>=5->dataframe_image) (1.5.5)
# Requirement already satisfied: tornado>=6.2 in d:\my new project workplace\vis-esrd-lab\salt_c\env\lib\site-packages (from jupyter-client>=6.1.5->nbclient>=0.5.0->nbconvert>=5->dataframe_image) (6.2)
# Requirement already satisfied: pyzmq>=23.0 in d:\my new project workplace\vis-esrd-lab\salt_c\env\lib\site-packages (from jupyter-client>=6.1.5->nbclient>=0.5.0->nbconvert>=5->dataframe_image) (23.2.1)
# Requirement already satisfied: entrypoints in d:\my new project workplace\vis-esrd-lab\salt_c\env\lib\site-packages (from jupyter-client>=6.1.5->nbclient>=0.5.0->nbconvert>=5->dataframe_image) (0.4)
# Requirement already satisfied: jsonschema>=2.6 in d:\my new project workplace\vis-esrd-lab\salt_c\env\lib\site-packages (from nbformat>=5.1->nbconvert>=5->dataframe_image) (4.14.0)
# Requirement already satisfied: fastjsonschema in d:\my new project workplace\vis-esrd-lab\salt_c\env\lib\site-packages (from nbformat>=5.1->nbconvert>=5->dataframe_image) (2.16.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in d:\my new project workplace\vis-esrd-lab\salt_c\env\lib\site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert>=5->dataframe_image) (0.18.1)
# Requirement already satisfied: attrs>=17.4.0 in d:\my new project workplace\vis-esrd-lab\salt_c\env\lib\site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert>=5->dataframe_image) (22.1.0)
# Requirement already satisfied: pytz>=2020.1 in d:\my new project workplace\vis-esrd-lab\salt_c\env\lib\site-packages (from pandas>=0.24->dataframe_image) (2022.2.1)
# Requirement already satisfied: six>=1.5 in d:\my new project workplace\vis-esrd-lab\salt_c\env\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.1->dataframe_image) (1.16.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in d:\my new project workplace\vis-esrd-lab\salt_c\env\lib\site-packages (from aiohttp->dataframe_image) (2.1.1)
# Requirement already satisfied: aiosignal>=1.1.2 in d:\my new project workplace\vis-esrd-lab\salt_c\env\lib\site-packages (from aiohttp->dataframe_image) (1.2.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in d:\my new project workplace\vis-esrd-lab\salt_c\env\lib\site-packages (from aiohttp->dataframe_image) (4.0.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\my new project workplace\vis-esrd-lab\salt_c\env\lib\site-packages (from aiohttp->dataframe_image) (6.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in d:\my new project workplace\vis-esrd-lab\salt_c\env\lib\site-packages (from aiohttp->dataframe_image) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\my new project workplace\vis-esrd-lab\salt_c\env\lib\site-packages (from aiohttp->dataframe_image) (1.3.1)
# Requirement already satisfied: idna>=2.0 in d:\my new project workplace\vis-esrd-lab\salt_c\env\lib\site-packages (from yarl<2.0,>=1.0->aiohttp->dataframe_image) (3.4)
# Requirement already satisfied: soupsieve>1.2 in d:\my new project workplace\vis-esrd-lab\salt_c\env\lib\site-packages (from beautifulsoup4->dataframe_image) (2.3.2.post1)
# Requirement already satisfied: webencodings in d:\my new project workplace\vis-esrd-lab\salt_c\env\lib\site-packages (from bleach->nbconvert>=5->dataframe_image) (0.5.1)
# Requirement already satisfied: certifi>=2017.4.17 in d:\my new project workplace\vis-esrd-lab\salt_c\env\lib\site-packages (from requests->dataframe_image) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\my new project workplace\vis-esrd-lab\salt_c\env\lib\site-packages (from requests->dataframe_image) (1.26.12)
# WARNING: You are using pip version 21.1.2; however, version 22.3 is available.
# You should consider upgrading via the 'D:\My New Project Workplace\VIS-eSRD-LAB\SALT_C\env\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import dataframe_image as dfi
#sample data load
# df = pd.read_csv('./data/sample_data_100.csv', dtype=str)

df = pd.read_csv('./data/my_data/catagorical.csv', dtype=str)

# %%
df
# Out:
#        Unnamed: 0 test_id    attr_id        attr_name      result  \
# 0           26365  100441   102181.0  LDL Cholesterol          **
# 1           26869  100441   102181.0  LDL Cholesterol          **
# 2           27486  100441   102181.0  LDL Cholesterol           -
# 3           27554  100441   102181.0  LDL Cholesterol          **
# 4           27590  100441   102181.0  LDL Cholesterol         ---
# ...           ...     ...        ...              ...         ...
# 521796    3529340  100401   101458.0     Urobilinogen      Absent
# 521797    3529342  101520   101853.0              AFB   Not found
# 521798    3529387  100450   100736.0      Anti-TB IgM  320.3 U/mL
# 521799    3529389  100105  3002953.0              IgG     < 100.0
# 521800    3529391  100803   100636.0   TB Ab Combined    Negative
#
#             test_group_name                          test_name    data_type
# 0       Lipid Profile Serum            Lipid Profile Serum (F)  Categorical
# 1       Lipid Profile Serum            Lipid Profile Serum (F)  Categorical
# 2       Lipid Profile Serum            Lipid Profile Serum (F)  Categorical
# 3       Lipid Profile Serum            Lipid Profile Serum (F)  Categorical
# 4       Lipid Profile Serum            Lipid Profile Serum (F)  Categorical
# ...                     ...                                ...          ...
# 521796                  NaN               Urobilinogen - Urine  Categorical
# 521797          Z. N. Stain          Pericardial Fluid for AFB  Categorical
# 521798                  NaN                        Anti-TB IgM  Categorical
# 521799                  NaN  Anti Measles Virus Ab (IgG & IgM)  Categorical
# 521800                  NaN     TB Ab Combined (IgG+IgM) (ICT)  Categorical
#
# [521801 rows x 8 columns]

# %%
df = df.drop(['Unnamed: 0'], axis=1)

# %%
df
# Out:
#        test_id    attr_id        attr_name      result      test_group_name  \
# 0       100441   102181.0  LDL Cholesterol          **  Lipid Profile Serum
# 1       100441   102181.0  LDL Cholesterol          **  Lipid Profile Serum
# 2       100441   102181.0  LDL Cholesterol           -  Lipid Profile Serum
# 3       100441   102181.0  LDL Cholesterol          **  Lipid Profile Serum
# 4       100441   102181.0  LDL Cholesterol         ---  Lipid Profile Serum
# ...        ...        ...              ...         ...                  ...
# 521796  100401   101458.0     Urobilinogen      Absent                  NaN
# 521797  101520   101853.0              AFB   Not found          Z. N. Stain
# 521798  100450   100736.0      Anti-TB IgM  320.3 U/mL                  NaN
# 521799  100105  3002953.0              IgG     < 100.0                  NaN
# 521800  100803   100636.0   TB Ab Combined    Negative                  NaN
#
#                                 test_name    data_type
# 0                 Lipid Profile Serum (F)  Categorical
# 1                 Lipid Profile Serum (F)  Categorical
# 2                 Lipid Profile Serum (F)  Categorical
# 3                 Lipid Profile Serum (F)  Categorical
# 4                 Lipid Profile Serum (F)  Categorical
# ...                                   ...          ...
# 521796               Urobilinogen - Urine  Categorical
# 521797          Pericardial Fluid for AFB  Categorical
# 521798                        Anti-TB IgM  Categorical
# 521799  Anti Measles Virus Ab (IgG & IgM)  Categorical
# 521800     TB Ab Combined (IgG+IgM) (ICT)  Categorical
#
# [521801 rows x 7 columns]

# %%
df.loc[df['result'].isin(['S','R','I'])]
# Out:
#        test_id    attr_id                attr_name result test_group_name  \
# 118521  100685   101622.0                 Cefixime      S             NaN
# 118522  100685   101624.0              Ceftriaxone      S             NaN
# 118523  100685   101625.0               Cefuroxime      S             NaN
# 118524  100685   101632.0             Levofloxacin      R             NaN
# 118525  100685   101633.0                Linezolid      R             NaN
# 118526  100685   101634.0               Mecillinam      R             NaN
# 118527  100685   101639.0               Amoxyclave      S             NaN
# 181337  101006  3000224.0               Tobramycin      S             NaN
# 181338  101006  3000087.0              Tigecycline      S             NaN
# 181339  101006   103519.0  Piperacillin/Tazobactum      S             NaN
# 181340  101006   103518.0                Meropenem      S             NaN
# 181341  101006   103517.0                 Colistin      S             NaN
# 181342  101006   103069.0               Cefotaxime      R             NaN
# 181343  101006   103064.0           Co-trimoxazole      R             NaN
# 181344  101006   103062.0              Ceftazidime      R             NaN
# 181345  101006   103061.0                 Cefepime      R             NaN
# 181346  101006   101812.0                 Amikacin      S             NaN
# 181347  101006   101811.0                Aztreonam      R             NaN
# 181348  101006   101810.0               Amoxyclave      R             NaN
# 181349  101006   101808.0               Netilmicin      S             NaN
# 181350  101006   101805.0               Gentamicin      S             NaN
# 181351  101006   101802.0            Ciprofloxacin      R             NaN
# 181352  101006   101800.0              Ceftriaxone      R             NaN
# 181353  101006   101799.0                 Cefixime      R             NaN
# 514317  101184  3002482.0             Donor Name :      S             NaN
#
#               test_name    data_type
# 118521    Urine for C/S  Categorical
# 118522    Urine for C/S  Categorical
# 118523    Urine for C/S  Categorical
# 118524    Urine for C/S  Categorical
# 118525    Urine for C/S  Categorical
# 118526    Urine for C/S  Categorical
# 118527    Urine for C/S  Categorical
# 181337      HVS for C/S  Categorical
# 181338      HVS for C/S  Categorical
# 181339      HVS for C/S  Categorical
# 181340      HVS for C/S  Categorical
# 181341      HVS for C/S  Categorical
# 181342      HVS for C/S  Categorical
# 181343      HVS for C/S  Categorical
# 181344      HVS for C/S  Categorical
# 181345      HVS for C/S  Categorical
# 181346      HVS for C/S  Categorical
# 181347      HVS for C/S  Categorical
# 181348      HVS for C/S  Categorical
# 181349      HVS for C/S  Categorical
# 181350      HVS for C/S  Categorical
# 181351      HVS for C/S  Categorical
# 181352      HVS for C/S  Categorical
# 181353      HVS for C/S  Categorical
# 514317  Stock W/B, PBRC  Categorical

# %%
g = df.groupby(['test_name','attr_name'], as_index = False)['result'].agg(['unique'])
g
# Out:
#                                                                                                                 unique
# test_name                                 attr_name
#  Urinary Protein (Spot)                   Urinary Protein (Spot)                                                 [(+)]
# 24 hrs Urine for AFB                      12 hrs Urine for AFB                                             [Not found]
#                                           24 hrs Urine for AFB                                             [Not found]
# A/G Ratio (Albumin & Globulin) Serum      A/G Ratio                  [1.48:1, 1.03:1, 1.26:1, 1.10:1, 1.20:1.0, 1.3...
# ABO grouping + Rh(D)typing + Hb screening 1. HBsAg                                                          [Negative]
# ...                                                                                                                ...
# Wound Swab for AFB                        AFB (Ziehl-Neelsen Stain)                                        [Not found]
#                                           Wound Swab for AFB                                               [Not found]
# Wound Swab for Gram Stain                 Gram stain                 [Few Gram negative bacilli seen., Few Gram pos...
# e-GFR (Estimated G. Filtration Rate)      ** Age                                        [69 Y, 63 Yrs, 73 Yrs, 54 Yrs]
#                                           Gender                                    [Female, Male, M,   Male,    Male]
#
# [888 rows x 1 columns]

# %%
[Not found, Positive (2+), Positive (1+), Positive (+), Positive (+++), Positive (3+), Positive (3+)., Positive (++), Incompatible],

# %%
Whole Blood, Compatible,absent, Not Found, Present, Autologous, Male, Normal, >>>>, Scanty, Not Done, Very Few, N/S,Incompatible], **, ***(LDL cholesterol)

# %%
s2count_df = df.groupby(['attr_name']).size().reset_index(name='counts').sort_values(['counts'], ascending=[False])

# %%
s2count_df
# Out:
#                    attr_name  counts
# 10                    Colour   12764
# 5                 Appearance   12756
# 20                     Sugar   12756
# 6              Blood Group :   11652
# 19                 Rh Type :   11649
# 7           Blood Group: ABO    4661
# 18                    Rh (D)    4661
# 13                    HBs Ag    4259
# 11       Dengue Ag NS1 (ICT)    3577
# 4                   Anti-HCV    3157
# 22                      VDRL    2138
# 17                     Mucus    1502
# 12              Fat Globules    1282
# 23           Vegetable Cells    1282
# 24                    Yeasts    1282
# 9                      Color    1282
# 0                    Albumin     676
# 2             Anti-HBc Total     220
# 15                     M.P.V     132
# 14  IgG Against Dengue Virus     115
# 1               Anti-HAV IgM     110
# 16          Malaria Ag (ICT)      65
# 8   Chikungunya Antibody IgM      22
# 3                   Anti-HBe      16
# 21            Toxoplasma IgM       6

# %%
s2count_df.to_csv("attr_name.csv")

# %%
df.drop(df[(df['attr_name'] == 'Nil')].index, inplace=True)

# %%
df.describe()
# Out:
#         test_id    attr_id attr_name result       test_group_name  \
# count     92022      91802     92022  92022                 45669
# unique       34         85        25     95                     5
# top     5003345  3000017.0    Colour    Nil  PHYSICAL EXAMINATION
# freq      36322      12108     12764  14797                 25511
#
#                                   test_name    data_type
# count                                 92022        92022
# unique                                   34            1
# top     Complete Urine Analysis (Urine R/E)  Categorical
# freq                                  36322        92022

# %%
df
# Out:
#       test_id    attr_id      attr_name    result       test_group_name  \
# 0      101497   100157.0          M.P.V      ----                   NaN
# 1      101497   100157.0          M.P.V      ----                   NaN
# 2      101497   100157.0          M.P.V       ---                   NaN
# 3      101497   100157.0          M.P.V      ----                   NaN
# 4      101497   100157.0          M.P.V      ----                   NaN
# ...       ...        ...            ...       ...                   ...
# 92029  101455  3002939.0          Sugar       Nil  CHEMICAL EXAMINATION
# 92030  207199  3002848.0  Blood Group :      "AB"                   NaN
# 92031  207199  3002849.0      Rh Type :  Negative                   NaN
# 92032  207199  3002854.0  Blood Group :      "AB"                   NaN
# 92033  207199  3002855.0      Rh Type :  Negative                   NaN
#
#                              test_name    data_type
# 0                                  CBC  Categorical
# 1                                  CBC  Categorical
# 2                                  CBC  Categorical
# 3                                  CBC  Categorical
# 4                                  CBC  Categorical
# ...                                ...          ...
# 92029  Urine Phase contrast microscopy  Categorical
# 92030                        Autologus  Categorical
# 92031                        Autologus  Categorical
# 92032                        Autologus  Categorical
# 92033                        Autologus  Categorical
#
# [92034 rows x 7 columns]

# %%
df = df[['attr_id','result']]

# %%
df.columns  = ['measurement_concept_id','value_source_value']

# %%
df
# Out:
#        measurement_concept_id value_source_value
# 0                    102181.0                 **
# 1                    102181.0                 **
# 2                    102181.0                  -
# 3                    102181.0                 **
# 4                    102181.0                ---
# ...                       ...                ...
# 521796               101458.0             Absent
# 521797               101853.0          Not found
# 521798               100736.0         320.3 U/mL
# 521799              3002953.0            < 100.0
# 521800               100636.0           Negative
#
# [521801 rows x 2 columns]

# %%
count = df.groupby(['value_source_value']).size()

# %%
df['value_source_value'].tolist()
# Out:
# ['----',
#  '----',
#  '---',
#  '----',
#  '----',
#  '----',
#  '----',
#  '----',
#  '----',
#  '----',
#  '----',
#  '----',
#  '----',
#  '----',
#  '---',
#  '----',
#  '----',
#  '----',
#  '----',
#  '---',
#  '----',
#  '>>>>',
#  '--',
#  '>>>>',
#  '-',
#  '>>>>',
#  '>>>>',
#  '--',
#  '--',
#  '>>>>',
#  '>>>>',
#  '>>>>',
#  '>>>>',
#  '--',
#  '>>>>',
#  '>>>>',
#  '>>>>',
#  '>>>>',
#  '--',
#  '>>>>',
#  '>>>>',
#  '>>>>',
#  '>>>>',
#  '>>>>',
#  '>>>>',
#  '>>>>',
#  '>>>>',
#  '>>>>',
#  '>>>>',
#  '>>>>',
#  '-----',
#  '>>>>',
#  '>>>>',
#  '>>>>',
#  '>>>>',
#  '>>>>',
#  '>>>>',
#  '---',
#  '---',
#  '>>>>',
#  '>>>>',
#  '>>>>',
#  '>>>>',
#  '>>>>',
#  '>>>>',
#  '--',
#  '----',
#  '----',
#  '----',
#  '>>>>',
#  '----',
#  '-----',
#  '>>>>',
#  '>>>>',
#  '---',
#  '>>>>',
#  '----',
#  '>>>>',
#  '--',
#  '>>>>',
#  '>>>>',
#  '----',
#  '----',
#  '>>>>',
#  '----',
#  '>>>>',
#  '----',
#  '>>>>',
#  '----',
#  '>>>>',
#  '>>>>',
#  '----',
#  '>>>>',
#  '>>>>',
#  '>>>>',
#  '---',
#  '----',
#  '>>>>',
#  '>>>>',
#  '>>>>',
#  '--',
#  '--',
#  '>>>>',
#  '----',
#  '--',
#  '>>>>',
#  '--',
#  '----',
#  '>>>>',
#  '----',
#  '>>>>',
#  '>>>>',
#  '---',
#  '>>>>',
#  '------',
#  '>>>>',
#  '>>>>',
#  '>>>>',
#  '>>>>',
#  '>>>>',
#  '>>>>',
#  '>>>>',
#  '>>>>',
#  '>>>>',
#  '----',
#  '----',
#  '----',
#  '----',
#  '----',
#  '----',
#  '>>>>',
#  '----',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Trace',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  '(+)',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  '(++)',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Trace',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  '(++)',
#  'Trace',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Hazy',
#  'Straw',
#  'Trace',
#  '(+)',
#  'Straw',
#  'Clear',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Trace',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Straw',
#  'Clear',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  '(+++)',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  '(++)',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Clear',
#  'Straw',
#  '(++)',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Yellow',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  '(++)',
#  '(++)',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  '(+)',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Trace',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Trace',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Hazy',
#  'Reddish',
#  'Nil',
#  'Trace',
#  'Hazy',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Straw',
#  'Clear',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  '(+)',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  '(++)',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  '(+)',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  '(+)',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  '(+)',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Clear',
#  'Straw',
#  '(+)',
#  '(+)',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  '(+)',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Yellow',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  '(+)',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Straw',
#  'Clear',
#  'Nil',
#  'Trace',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  '(+)',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Trace',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  '(++)',
#  'Clear',
#  'Straw',
#  '(++)',
#  '(+++)',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Trace',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  '(+)',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  '(+++)',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Trace',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Straw',
#  'Clear',
#  '(++)',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Trace',
#  '(++)',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Trace',
#  'Clear',
#  'Straw',
#  'Nil',
#  '(+)',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Hazy',
#  'Straw',
#  '(+)',
#  '(+++)',
#  'Clear',
#  'Straw',
#  '(+)',
#  'Trace',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Hazy',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  '(++)',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Trace',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  '(+)',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Hazy',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  '(++)',
#  '(+)',
#  'Clear',
#  'Straw',
#  'Nil',
#  '(++)',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  '(+)',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Hazy',
#  'Straw',
#  '(+)',
#  '(++)',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  '(++)',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Trace',
#  'Clear',
#  'Straw',
#  '(+)',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Yellow',
#  'Nil',
#  'Trace',
#  'Clear',
#  'Straw',
#  '(++)',
#  '(+)',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  '(+)',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Trace',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Hazy',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Hazy',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  'Clear',
#  'Straw',
#  'Nil',
#  'Nil',
#  ...]

# %%
count
# Out:
# value_source_value
#  "B"            1
#  "O"            2
#  Positive       1
# "A              1
# "A"          3682
#              ...
# YELLOW         11
# Yellow        206
# Yellowish     190
# p               1
# positive        5
# Length: 95, dtype: int64

# %%
plot = count.plot.barh(y='mass', figsize=(5, 15))

# %%
# 1) Data preparation
from collections import defaultdict
import re

def _general_preprocessing(df):
    
    # window user_encoding
    df['value_source_value'] = df['value_source_value'].str.encode('utf8', errors = 'strict').str.decode('utf8', errors = 'strict')
    
    # lower, strip space, \d\+ restore
    df['value_source_value'] = df['value_source_value'].str.lower()
    df['value_source_value'] = df['value_source_value'].str.strip()
    df['value_source_value'] = df['value_source_value'].str.replace('"',"")
    df['value_source_value'] = df['value_source_value'].str.replace('(',"")
    df['value_source_value'] = df['value_source_value'].str.replace(')',"")



    df['value_source_value'] = df['value_source_value'].str.replace(r'(\d)(\+)', lambda x: x.groups()[1]*int(x.groups()[0]))
    df['value_source_value'] = df['value_source_value'].str.replace(r'(\d+)(\s+)(\++)', lambda x: x.groups()[2])
    df['value_source_value'] = df['value_source_value'].str.replace(r'(\++)(\d+)(\s+)', lambda x: x.groups()[0])
    
    #replace + to Rh+ only for 'HJ1UHH1'(Rh type laboratory code) 
    _rh_pos_df = df[df['measurement_concept_id'] == 'BL7002']['value_source_value'].str.replace('+','rh+')
    _rh_neg_df = df[df['measurement_concept_id'] == 'BL7002']['value_source_value'].str.replace('-','rh-')
    df.loc[df.measurement_concept_id == 'HJ1UHH1', 'value_source_value'] = _rh_pos_df 
    df.loc[df.measurement_concept_id == 'HJ1UHH1', 'value_source_value'] = _rh_neg_df
    return df

df_with_freq = df.groupby(df.columns.tolist()).size().reset_index(name = 'Freq')
df_with_freq_sort = df_with_freq.sort_values(by = 'Freq',ascending = False)
df_cleaned = _general_preprocessing(df_with_freq_sort)
df_cleaned_regrouped = df_cleaned.groupby(['measurement_concept_id','value_source_value'])
df_cleaned_sort = df_cleaned_regrouped.sum().reset_index().sort_values(by = 'Freq', ascending = False)

dist_dicts = defaultdict(dict)

for cid, value, freq in df_cleaned_sort.values:
    dist_dicts[cid][value] = freq
    
dist_dicts = dict(dist_dicts)
print(dist_dicts)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17328\484871900.py:14: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['value_source_value'] = df['value_source_value'].str.replace('(',"")
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17328\484871900.py:15: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['value_source_value'] = df['value_source_value'].str.replace(')',"")
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17328\484871900.py:19: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['value_source_value'] = df['value_source_value'].str.replace(r'(\d)(\+)', lambda x: x.groups()[1]*int(x.groups()[0]))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17328\484871900.py:20: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['value_source_value'] = df['value_source_value'].str.replace(r'(\d+)(\s+)(\++)', lambda x: x.groups()[2])
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17328\484871900.py:21: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['value_source_value'] = df['value_source_value'].str.replace(r'(\++)(\d+)(\s+)', lambda x: x.groups()[0])
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17328\484871900.py:24: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   _rh_pos_df = df[df['measurement_concept_id'] == 'BL7002']['value_source_value'].str.replace('+','rh+')
# {'3000045.0': {'nil': 12110, 'v': 1}, '3000018.0': {'nil': 12105, '+': 1, 'few': 1}, '3000041.0': {'nil': 12103, '+': 3, 'few': 2, 'present': 1, '++': 1}, '3000039.0': {'nil': 12077, '+': 30, 'few': 1, '++': 1}, '3000067.0': {'nil': 12076, 'normal': 10, '++': 8, '+': 5, '+++': 3}, '3000032.0': {'absent': 12067, 'nil': 34, '+': 6}, '3000026.0': {'nil': 12050, '+': 8, 'few': 3, 'absent': 2, 'plenty': 2, '++': 1, 'p': 1}, '3000048.0': {'nil': 12047, '0-1': 31, '+': 20, 'few': 6, '1-2': 6, '++': 1, '5-14': 1}, '3000040.0': {'nil': 12047, '+': 37, 'few': 14, '++': 9, 'plenty': 1, '+++': 1}, '3000013.0': {'normal': 12041, 'nil': 38, 'absent': 16, 'normal.': 6, '+': 5, '++++': 1, 'plenty': 1}, '3000015.0': {'nil': 11972, '+': 97, '++': 27, 'trace': 7, 'present': 3, '+++': 1, 'hazy': 1}, '3000005.0': {'absent': 11968, 'present': 113, '+': 11, 'present +': 5, '++': 4, 'not done': 3, 'present ++': 3, '+++': 1}, '3000047.0': {'nil': 11934, '+': 75, '0-1': 33, '++': 28, 'few': 28, 'a few': 5, '1-2': 3, 'occasional': 3, '4-5': 1, 'scanty': 1, '+++': 1}, '3000029.0': {'absent': 11912, 'nil': 180, '++': 7, '+++': 4, '+': 2, 'not done': 1}, '3000027.0': {'nil': 11878, '0-1': 30, '1-2': 4, '14.50 -': 1, '2-4': 1, '4-5': 1, 'granules +': 1, 'granule a few': 1, 'granular +': 1, 'fine granular': 1}, '3000025.0': {'nil': 11837, '+': 77, '++': 51, 'trace': 39, '0-1': 35, 'few': 34, '+++': 16, 'plenty': 6, 'present': 3, '9.9 -': 2, 'absent': 2, '1-5': 1, 's': 1, 'scanty': 1, 'very few': 1}, '3000028.0': {'nil': 11821, '+': 156, 'few': 81, '++': 28, 'a few': 15, '+++': 3, 'very few': 1, 'plenty': 1, 'a  few': 1}, '3000017.0': {'clear': 11763, 'hazy': 254, 'turbid': 91}, '3000020.0': {'straw': 11744, 'yellow': 182, 'reddish': 74, 'amber': 32, 'l yellow': 28, 'deep straw': 17, 'dark brown': 7, 'turbid': 5, 'yellowish': 4, 'dark straw': 3, 'red': 3, 'brown': 2, 'dark yellow': 1, 'deep starw': 1, 'deep yellow': 1, 'dk brown': 1, 'dk brown  06': 1, 'pale yellow': 1}, '3000016.0': {'nil': 11393, '+': 299, '++': 211, '+++': 178, 'trace': 24, 'absent': 2, 'normal': 1}, '3000037.0': {'nil': 10548, '++': 615, '+': 468, '+++': 249, 'trace': 197, '++++': 30}, '3000003.0': {'nil': 8396, '+': 1313, 'trace': 1217, '++': 830, '+++': 322, '++++': 29, 'tarce': 1}, '3002242.0': {'n/s': 7849, 'nil': 806, '++': 43, '+': 35, '+++': 21, 'trace': 10, 'nil.': 5, '++++': 2, 'nill': 1, 'n?s': 1, 'n/s.': 1}, '3000022.0': {'nil': 4735, '0-2': 2737, '0-1': 1890, '2-4': 432, '1-2': 361, '1-3': 251, '2-5': 250, 'plenty': 242, '0-3': 142, '2-6': 130, '2-3': 120, '5-10': 101, '15-20': 90, '4-6': 68, '10-15': 53, '10-12': 42, '4-8': 40, '3-5': 35, '8-12': 34, '20-25': 28, '6-10': 23, '2-7': 23, '12-15': 22, '3-6': 21, '20-30': 20, '35-40': 20, '10-20': 17, '5-8': 17, '25-30': 16, '6-12': 15, '30-35': 12, '6-8': 12, '15-25': 12, '1-4': 9, '12-16': 9, '45-50': 8, '30-40': 7, '5-7': 7, '40-50': 6, '8-10': 5, '20-40': 5, '0-4': 4, '2-8': 4, '3-4': 3, '15-18': 3, '12-17': 3, '3-7': 3, '5-9': 3, '7-10': 2, '9-19': 2, '40-60': 2, '40-45': 2, '20-15': 1, '29-49': 1, '49-99': 1, '99.0 -': 1, 'occasional': 1, '16-20': 1, '15-30': 1, '14-18': 1, '12-14': 1, '10-14': 1}, '3000014.0': {'0-2': 4619, '2-4': 1344, '1-2': 811, '0-1': 709, 'plenty': 691, '1-3': 381, '2-5': 297, '2-6': 270, '3-5': 255, '12-15': 205, '15-20': 184, '2-3': 173, '8-12': 163, '20-25': 151, '4-8': 150, '10-15': 142, '5-7': 139, '4-6': 134, '10-12': 133, '5-8': 121, '6-10': 102, '5-10': 90, '0-3': 73, '3-6': 72, '25-30': 60, '6-12': 51, '6-8': 51, '30-35': 47, '20-30': 42, '2-7': 39, '10-20': 38, '3-7': 37, '12-16': 34, '35-40': 31, '12-17': 20, '20-40': 20, '15-18': 19, '15-25': 19, 'nil': 18, '10-14': 17, '2-8': 14, '30-40': 13, '1-5': 13, '18-22': 11, '14-18': 9, '3-8': 8, '8-10': 7, '40-45': 5, '12-18': 5, '10-16': 4, '45-50': 4, '40-60': 4, '40-50': 4, '4-7': 4, '16-22': 4, '20-24': 4, '1-4': 3, '8-15': 3, '4-5': 3, '18-20': 2, '7-10': 2, '9-19': 2, '5-9': 2, '3-4': 2, '29-49': 2, '0-4': 2, '49-99': 1, '5-6': 1, '6-9': 1, ...

# %%
# 2) Laboratory tests Categorization
import re
import collections, re


def get_majors_and_minors(dist_dict, acc_thr=99.5, diff_thr=100, n_thr=9):

    if len(dist_dict) < 5:
        return dist_dict

    total = sum(dist_dict.values())
    
    tmp = {}
    sorted_dist_dict = sorted(dist_dict.items(), key=lambda t: -t[1])
    
    for idx, (k, v) in enumerate(sorted_dist_dict):
        
        if idx==0:
            prev = v
            prev_acc = 0

        acc_ratio = (prev_acc + v) / total * 100
        
        #Escape Rules
        if (acc_ratio >= acc_thr): 
            tmp.update({k:v})
            break
            
        if (idx>n_thr): 
            break
            
        tmp.update({k:v})
        prev = v
        prev_acc += v
        
    return tmp


def get_groups(majors,
    rules_A = ['straw','clear','cloudy','yellow','amber','brown','orange'],
    rules_B = ['++', '+++', '++++'],
    rules_C = ['po.*', 'ne.*'],
    rules_D = ['ab','rh+'],
    rules_E = ['rea.*', 'non.*'],
    rules_F = ['nil.*', 'few*'],
    rules_G = ['i.*', 's.*', 'r.*']):

    group_A = [] 
    group_B = [] 
    group_C = [] 
    group_D = []  
    group_E = []
    group_F =[]
    group_G = []

    message_form = '\n'.join(['Rules_%s: {}' % c for c in 'ABCDEFG'])
    print(message_form.format(rules_A, rules_B, rules_C,rules_D, rules_E, rules_F,rules_G))
    
    def is_group_A(major_dict):
        return sum([1 for k in major_dict.keys() if k in rules_A])
    def is_group_B(major_dict):
        return sum([1 for k in major_dict.keys() if k in rules_B])
    def is_group_C(major_dict):
        return sum([1 for s in major_dict.keys() for r in rules_C if re.findall(r, s)])
    def is_group_D(major_dict):
        return sum([1 for k in major_dict.keys() if k in rules_D])
    def is_group_E(major_dict):
        return sum([1 for s in major_dict.keys() for r in rules_E if re.findall(r,s)])
    def is_group_F(major_dict):
        return sum([1 for k in major_dict.keys() for k in rules_F ])
    def is_group_G(major_dict):
        return sum([1 for s in major_dict.keys() for r in rules_G if re.findall(r,s)])

    for table_cid, major_dict in majors.items():
        
        if is_group_A(major_dict): 
            group_A.append(table_cid)
            
        elif is_group_B(major_dict):
            group_B.append(table_cid)
            
        elif is_group_C(major_dict):
            group_C.append(table_cid)
            
        elif is_group_D(major_dict): 
            group_D.append(table_cid)
            
        elif is_group_E(major_dict):
            group_E.append(table_cid)
        elif is_group_F(major_dict):
            group_F.append(table_cid)
        elif is_group_F(major_dict):
            group_G.append(table_cid)
            

    merge_group_set = set(group_A + group_B + group_C + group_D + group_E+group_F+group_G)
    group_others = [table_cid for table_cid in majors.keys() if table_cid not in merge_group_set]
    return [group_A, group_B, group_C, group_D, group_E,group_F,group_G, group_others]


def get_group_dict(group, regex=lambda x:x):
    
    group_dict = defaultdict(int)
               
    for table_cid in group:
        for k, v in dist_dicts[table_cid].items():
            group_dict[regex(re.sub(r'\s+', ' ', k))] += v
    
    return group_dict


majors = {table_cid:get_majors_and_minors(dist_dict, acc_thr=99.5) 
          for table_cid, dist_dict in dist_dicts.items()}
groups = get_groups(majors)
groups_dict = [get_group_dict(group) for group in groups] 
groups_sample = [group_dict.keys() for group_dict in groups_dict]
# Out:
# Rules_A: ['straw', 'clear', 'cloudy', 'yellow', 'amber', 'brown', 'orange']
# Rules_B: ['++', '+++', '++++']
# Rules_C: ['po.*', 'ne.*']
# Rules_D: ['ab', 'rh+']
# Rules_E: ['rea.*', 'non.*']
# Rules_F: ['nil.*', 'few*']
# Rules_G: ['i.*', 's.*', 'r.*']

# %%
from itertools import chain
import pandas as pd
from scipy import spatial


class Mapper():
    def __init__(self, samples, ref_list):
        self.samples = samples
        self.ref_list = ref_list
        
    def create_feature_matrix(self, samples1, samples2):
        def _create_feature_matrix(samples, refs):
            #refs는 feature list
            result = []
            row_idx = []
            for r_idx, ng_str in enumerate(samples):
                result.append([0]*len(refs))
                for ng_char in ng_str:
                    result[r_idx][refs.index(ng_char)] += 1
            return result

        samples1 = [s.lower() for s in samples1]
        samples2 = [s.lower() for s in samples2]
        refs = list(set(chain.from_iterable(samples1+samples2)))
        matrix1 = _create_feature_matrix(samples1, refs)
        matrix2 = _create_feature_matrix(samples2, refs)
        return matrix1, matrix2
    
    def assign_to_ref(self, sample_vectors, ref_vectors, sample_list, ref_list):
        def cosine_similarity_matrix(matrix1, matrix2):

            distance = []
            for s_idx, sample in enumerate(matrix1):
                distance.append([])
                for ref in matrix2:
                    distance[s_idx].append(
                        round(1-spatial.distance.cosine(sample, ref),2)
                    )
            return distance
        
        def lp_dist_matrix(matrix1, matrix2):
            distance = []
            for s_idx, sample in enumerate(matrix1):
                distance.append([])
                for ref in matrix2:
                    distance[s_idx].append(
                        round(spatial.distance.euclidean(sample, ref),2)
                    )
            return distance
        
        def levenshtein_measure(sample_list, ref_list):
            def levenshtein(s1, s2):
            # based on Wikipedia/Levenshtein_distance
                if len(s1) < len(s2):
                    return levenshtein(s2, s1)

                if len(s2) == 0:
                    return len(s1)
    
                previous_row = range(len(s2) + 1)
                for i, c1 in enumerate(s1):
                    current_row = [i + 1]
                    for j, c2 in enumerate(s2):
                        insertions = previous_row[j + 1] + 1
                        deletions = current_row[j] + 1
                        substitutions = previous_row[j] + (c1 != c2)
                        current_row.append(min(insertions, deletions, substitutions))
                    previous_row = current_row
    
                return previous_row[-1]
    
            distance = []
            for s_idx, sample in enumerate(sample_list):
                distance.append([])
                for ref in ref_list:
                    distance[s_idx].append(levenshtein(sample, ref))
            return distance

        
        sample_list = list(sample_list)

        cos_scores = cosine_similarity_matrix(sample_vectors, ref_vectors)
        lev_scores  = levenshtein_measure(sample_list, ref_list)
        lp_dist_scores = lp_dist_matrix(sample_vectors, ref_vectors)
        
        result = []
        outlier = []
        for s_idx, sample in enumerate(sample_vectors):
            max_cos_score = max(cos_scores[s_idx])
            max_cos_idx = cos_scores[s_idx].index(max_cos_score)
            max_cos_cnt = cos_scores[s_idx].count(max_cos_score)
            min_lp_dist_score = min(lp_dist_scores[s_idx])
            min_lp_dist_idx = lp_dist_scores[s_idx].index(min_lp_dist_score)
            min_lp_dist_cnt = lp_dist_scores[s_idx].count(min_lp_dist_score)
            min_lev_score = min(lev_scores[s_idx])
            min_lev_idx = lev_scores[s_idx].index(min_lev_score)
            
            if max_cos_cnt == len(cos_scores[s_idx]):
                outlier.append(
                    [sample_list[s_idx],
                     ref_list[max_cos_idx],
                     cos_scores[s_idx]]
                )
            else:
                result.append(
                    [sample_list[s_idx],
                     ref_list[max_cos_idx],
                     cos_scores[s_idx],
                     ref_list[min_lp_dist_idx],
                     lp_dist_scores[s_idx],
                     ref_list[min_lev_idx],
                     lev_scores[s_idx],
                     'cosine' if max_cos_cnt <= 1 else 'Eucl',
                     ref_list[max_cos_idx] if max_cos_cnt <= 1 else ref_list[min_lp_dist_idx]]
                )

        return result, outlier
    
    def get_report_df(self, results):

        report_df = pd.DataFrame(
            results,
            columns=[
                'Data',
                'cos_word',
                'cos_score',
                'euc_word',
                'euc_score',
                'lev_word',
                'lev_score',
                'Measure',
                'Final'
            ]
        )
        report_df = report_df[['Data','Final']]
        return report_df
    
    def analyze(self):
        self._sample_vectors, self._ref_vectors = self.create_feature_matrix(
            self.samples, self.ref_list)
        
        self._cluster_results, self._outlier = self.assign_to_ref(
            self._sample_vectors, self._ref_vectors, self.samples, self.ref_list)
        
        self.report_df= self.get_report_df(self._cluster_results)

        
ref_list_A = ['straw', 'amber', 'brown', 'green', 'yellow', 'orange', 'black','blue', 'red', 'other', 'clear', 'cloudy', 'hazy', 'turbid', 'bloody','white']
ref_list_B = ['neg', 'trace', '+', '++', '+++', '++++']
ref_list_C = ['posi', 'neg-','weak-pos']
ref_list_D = ['a','b','c','ab','cisab','rh+','rh-','partiald','weakd','variantd'] 
ref_list_E = ['reac', 'non-reac','weak-reac']
ref_list_F = ['nil', 'few']
ref_list_G = ['s', 'i', 'r']

groups_agents = [
    Mapper(sample, ref_list) for sample, ref_list in zip(
        groups_sample[:-1],
        [ref_list_A, ref_list_B, ref_list_C,ref_list_D,ref_list_E, ref_list_F, ref_list_G]
    )
]

for agent in groups_agents:
    agent.analyze()

# %%
# 4) Result table
groups_agents[0].report_df
# Out:
#            Data   Final
# 0         clear   clear
# 1          hazy    hazy
# 2        turbid  turbid
# 3         straw   straw
# 4        yellow  yellow
# 5       reddish     red
# 6         amber   amber
# 7      l yellow  yellow
# 8    deep straw     red
# 9    dark brown   brown
# 10    yellowish  yellow
# 11   dark straw   straw
# 12          red     red
# 13        brown   brown
# 14  pale yellow  yellow
# 15  dark yellow  yellow
# 16   deep starw     red
# 17  deep yellow  yellow
# 18     dk brown   brown
# 19  dk brown 06   brown
# 20     greenish   green
# 21      whitish   white
# 22     blackish   black
# 23     brownish   brown
# 24     whitiesh   white
# 25       redish     red
# 26        white   white
# 27       watery   straw
# 28   deep brown     red

# %%
groups_agents[1].report_df
# Out:
#                     Data  Final
# 0                    nil    neg
# 1                     ++     ++
# 2                      +      +
# 3                    +++    +++
# 4                  trace  trace
# 5                   ++++   ++++
# 6                    few    neg
# 7                  a few  trace
# 8               very few  trace
# 9                 scanty  trace
# 10  few, veg: fibre: few    neg

# %%
groups_agents[2].report_df
# Out:
#               Data     Final
# 0     positive +ve      posi
# 1     negative -ve      neg-
# 2         positive      posi
# 3         negative      neg-
# 4          positve      posi
# 5                p      posi
# 6  weakly positive  weak-pos
# 7     non-reactive      neg-
# 8        negative.      neg-

# %%
groups_agents[3].report_df
# Out:
#       Data Final
# 0        b     b
# 1        a     a
# 2       ab    ab
# 3       a`     a
# 4      ab`    ab
# 5    ''b''     b
# 6    ''a''     a
# 7   ''ab''    ab
# 8       a'     a
# 9      a''     a
# 10     'b'     b

# %%
groups_agents[4].report_df
# Out:
#            Data     Final
# 0  non-reactive  non-reac
# 1  non reactive  non-reac
# 2      reactive      reac

# %%
groups_agents[5].report_df
# Out:
#      Data Final
# 0     nil   nil
# 1   trace   few
# 2  watery   few
# 3  turbid   nil

# %%
groups_agents[6].report_df
# Out:
# Empty DataFrame
# Columns: [Data, Final]
# Index: []

# %%
result_appearance = groups_agents[0].report_df

# %%
dfi.export(result_appearance, "./result_apeearn.png")

# %%
groups_agents[1].report_df
# Out:
#                     Data  Final
# 0                    nil    neg
# 1                     ++     ++
# 2                      +      +
# 3                    +++    +++
# 4                  trace  trace
# 5                   ++++   ++++
# 6                    few    neg
# 7               very few  trace
# 8                  a few  trace
# 9                 scanty  trace
# 10  few, veg: fibre: few    neg

# %%
groups_agents[5].report_df
# Out:
#      Data Final
# 0     nil   nil
# 1   trace   few
# 2  watery   few
# 3  turbid   nil

# %%
result_neg_pos  = groups_agents[2].report_df

# %%
dfi.export(result_neg_pos, "./result_neg_pos.png")

# %%
result_ab = groups_agents[3].report_df

# %%
dfi.export(result_ab, "./result_ab.png")

# %%
result_reac = groups_agents[4].report_df

# %%
dfi.export(result_reac, "./result_reac.png")

# %%
print(29+11+9+11+3)
# Out:
# 63

# %%
(53/95) * 100
# Out:
# 55.78947368421052

# %%
# first salt c = 40.47 %
#
# corectly catagorizing = 36.90 %

# %%
# initial catagorize = 54.76 %
#correct catagorize = 44.05 %
